# %% [markdown]
# # NLP Fundamentals with Python
# ---------------------------------
# #### Notebook created from the exercises
#
# - NLP - Field of study focussed on understanding the language (Natural languages)
#
# - NLP = NLU + NLG (Understanding & Generation)
#
# Familiar NLP Applications include:
# - Converstational Bots / Chat Bots
# - Sentiment Analysis
# - Language Translation Services
# - many more

# %% [markdown]
# <img src="files/image1.jpg">

# %% [markdown]
# #### Important / Common Packages for NLP in Python include the following:
#
#     1. NLTK - Natural language toolkit
#     2. Re - The good old Regular expressions
#     3. Spacy
#     4.

# %% [markdown]
# ### Intro to Regular Expressions in Python
#
# - Regular Expression Basics.
# - Python package for Reg Exp is "re"

# %% [markdown]
# #### 1. Pattern Matching : Words and Sentences

# %% [markdown]
# <img src="files/re_patterns.png">

# %%
import re

# %%
re.match("hello", "hello world")
# Out:
# <_sre.SRE_Match object; span=(0, 5), match='hello'>

# %% [markdown]
# Matching for any word is done with \w

# %%
word_ex = '\w+'
re.match(word_ex, 'hi')
# Out:
# <_sre.SRE_Match object; span=(0, 2), match='hi'>

# %%
my_string = "Let's write Some Regular expressions in MixedCase!"
# Find all words & all letters (removes punctuation characters)
split_words_list = re.findall(r"\w+", my_string)
# re.findall(r"\w", my_string)

print(split_words_list)
# Out:
# ['Let', 's', 'write', 'Some', 'Regular', 'expressions', 'in', 'MixedCase']

# %% [markdown]
# - So you can use re.findall for tokenization! One of the many methods available in python!!
# - re.split is a better option

# %%
for word in split_words_list:
    print(word.lower())
# Out:
# let
# s
# write
# some
# regular
# expressions
# in
# mixedcase

# %% [markdown]
# Lets now try to break a paragraph into sentences.

# %%
my_string = "Let's write RegEx!  Won't that be fun?  I sure think so.  Can you find 4 sentences?  Or perhaps, all 19 words?"

# Write a pattern to match sentence endings: sentence_endings
sentence_endings = r"[.?!]"

# Split my_string on sentence endings and print the result
print(re.split(sentence_endings, my_string))
# Out:
# ["Let's write RegEx", "  Won't that be fun", '  I sure think so', '  Can you find 4 sentences', '  Or perhaps, all 19 words', '']

# %%
# Find all capitalized words in my_string and print the result
capitalized_words = r"[A-Z]\w+"
print(re.findall(capitalized_words, my_string))
# Out:
# ['Let', 'RegEx', 'Won', 'Can', 'Or']

# %%
# Split my_string on spaces and print the result
spaces = r"\s+"
print(re.split(spaces, my_string))
# Out:
# ["Let's", 'write', 'RegEx!', "Won't", 'that', 'be', 'fun?', 'I', 'sure', 'think', 'so.', 'Can', 'you', 'find', '4', 'sentences?', 'Or', 'perhaps,', 'all', '19', 'words?']

# %%
# Find all digits in my_string and print the result
digits = r"\d+"
print(re.findall(digits, my_string))
# Out:
# ['4', '19']

# %% [markdown]
# ## Introducing "nltk" package.
#
# Natural language Tool kit, that provides wrappers for commong text processing activites.
# Install nltk if not available in your python environment

# %%
import nltk
from nltk import sent_tokenize, word_tokenize

# %%
filename = "scene_one.txt"
file = open(filename, "r")
scene_one = file.read()
scene_one
# Out:
# "SCENE 1: [wind] [clop clop clop] \\nKING ARTHUR: Whoa there!  [clop clop clop] \\nSOLDIER #1: Halt!  Who goes there?\\nARTHUR: It is I, Arthur, son of Uther Pendragon, from the castle of Camelot.  King of the Britons, defeator of the Saxons, sovereign of all England!\\nSOLDIER #1: Pull the other one!\\nARTHUR: I am, ...  and this is my trusty servant Patsy.  We have ridden the length and breadth of the land in search of knights who will join me in my court at Camelot.  I must speak with your lord and master.\\nSOLDIER #1: What?  Ridden on a horse?\\nARTHUR: Yes!\\nSOLDIER #1: You're using coconuts!\\nARTHUR: What?\\nSOLDIER #1: You've got two empty halves of coconut and you're bangin' 'em together.\\nARTHUR: So?  We have ridden since the snows of winter covered this land, through the kingdom of Mercea, through--\\nSOLDIER #1: Where'd you get the coconuts?\\nARTHUR: We found them.\\nSOLDIER #1: Found them?  In Mercea?  The coconut's tropical!\\nARTHUR: What do you mean?\\nSOLDIER #1:
# ...

# %%
# nltk.download()
# Tokenize Sentences 
# Since imported sent_tokenize explicitly, no need to prefix with "nltk."

sentences = nltk.sent_tokenize(scene_one)

for sentence in sentences:
    print(sentence + "\n")
# Out:
# SCENE 1: [wind] [clop clop clop] \nKING ARTHUR: Whoa there!
#
# [clop clop clop] \nSOLDIER #1: Halt!
#
# Who goes there?\nARTHUR: It is I, Arthur, son of Uther Pendragon, from the castle of Camelot.
#
# King of the Britons, defeator of the Saxons, sovereign of all England!\nSOLDIER #1: Pull the other one!\nARTHUR: I am, ...  and this is my trusty servant Patsy.
#
# We have ridden the length and breadth of the land in search of knights who will join me in my court at Camelot.
#
# I must speak with your lord and master.\nSOLDIER #1: What?
#
# Ridden on a horse?\nARTHUR: Yes!\nSOLDIER #1: You're using coconuts!\nARTHUR: What?\nSOLDIER #1: You've got two empty halves of coconut and you're bangin' 'em together.\nARTHUR: So?
#
# We have ridden since the snows of winter covered this land, through the kingdom of Mercea, through--\nSOLDIER #1: Where'd you get the coconuts?\nARTHUR: We found them.\nSOLDIER #1: Found them?
#
# In Mercea?
#
# ...

# %%
# Use word_tokenize to tokenize the fourth sentence: tokenized_sent
# Since you imported work_tokenize explicitly, no need to prefix "nltk."
sentences = ['I am a little star', 'Will become a super star', 'I am a cute boy','but also a talented boy' ]
tokenized_sent = nltk.word_tokenize(sentences[0])

print(tokenized_sent)
# Out:
# ['I', 'am', 'a', 'little', 'star']

# %%
# Make a set of unique tokens in the entire scene: unique_tokens
# set creates the unique set of words into an array

unique_tokens = set(word_tokenize(scene_one))
print(unique_tokens)
# Out:
# {'carried', 'may', 'Pendragon', 'get', 'are', 'grip', 'times', 'trusty', '2', 'You', 'there', 'Camelot', 'ratios', 'son', 'where', 'Who', 'Are', 'use', 'am', '!', 'of', 'an', 'back', 'why', 'Not', 'right', 'Ridden', 'SCENE', 'We', 'bangin', 'Saxons', 'Supposing', 'to', 'European', 'with', 'two', 'master.\\nSOLDIER', 'tropical', 'Whoa', 'strangers', 'grips', 'second', 'court', 'migrate', 'lord', 'martin', 'coconut.\\nARTHUR', 'King', 'Oh', 'in', 'house', 'ounce', 'if', 'every', 'this', 'Pull', 'No', 'found', "'em", 'That', '?', 'that.\\nARTHUR', '.', 'snows', 'speak', 'it', 'husk', 'horse', 'Arthur', '--', 'one', '...', 'course', 'What', 'my', 'They', 'yet', 'pound', 'guiding', 'climes', 'servant', 'then', 'through', 'maintain', 'velocity', 'covered', 'bring', 'needs', 'line.\\nSOLDIER', 'at', 'interested', "'", 'breadth', 'suggesting', 'coconuts', 'a', 'these', 'length', 'they', 'But', 'Found', 'Wait', 'winter', 'temperate', 'carried.\\nSOLDIER', 'point.\\nSOLDIER', 'other', 'carryin
# ...

# %% [markdown]
# #### re.match vs re.search
# match() looks for pattern from beginning where as search() looks for pattern anywhere.

# %%
my_string = "SOLDIER #1: Found them? In Mercea? The coconut's tropical!"

# %%
# Search for the first occurrence of "coconuts" in scene_one: match
match = re.search("coconuts", scene_one)

## Sentences 
sentences = ['There are lot of insights that can be extracted from Text',
             'Tokenization of text is often the rist step in text data prep',
             'nltk: package provides multiple wrappers for tokenzing']

# Print the start and end indexes of match
print(match.start(), match.end())
# Out:
# 588 596

# %%
# Write a regular expression to search for anything in square brackets: pattern1
pattern1 = r"\[.*\]"

# Use re.search to find the first text in square brackets
print(re.search(pattern1, scene_one))
# Out:
# <_sre.SRE_Match object; span=(9, 2274), match="[wind] [clop clop clop] \\nKING ARTHUR: Whoa ther>

# %%
# Find the script notation at the beginning of the third sentence and print it
pattern2 = r"[\w\s]+:"
print(re.match(pattern2, sentences[2]))
# Out:
# <_sre.SRE_Match object; span=(0, 5), match='nltk:'>

# %% [markdown]
# #### Advanced Tokinization with RegEx
# Tokenization functionality can be extended with OR ("|")
# Mention group using ()
# Mention explicit character range using []

# %%
# Import the necessary modules
import re
from nltk.tokenize import regexp_tokenize, TweetTokenizer

tweets = ['This is the best #nlp exercise ive found online! #python',
 '#NLP is super fun! <3 #learning',
 'Thanks @datacamp :) #nlp #python']

# Define a regex pattern to find hashtags: pattern1
pattern1 = r"#\w+"

# Use the pattern on the first tweet in the tweets list
regexp_tokenize(tweets[0], pattern1)
# Out:
# ['#nlp', '#python']

# %%
# Write a pattern that matches both mentions and hashtags
pattern2 = r"([@|#]\w+)"

# Use the pattern on the last tweet in the tweets list
regexp_tokenize(tweets[-1], pattern2)
# Out:
# ['@datacamp', '#nlp', '#python']

# %%
# Use the TweetTokenizer to tokenize all tweets into one list
tknzr = TweetTokenizer()
all_tokens = [tknzr.tokenize(t) for t in tweets]
print(all_tokens)
# Out:
# [['This', 'is', 'the', 'best', '#nlp', 'exercise', 'ive', 'found', 'online', '!', '#python'], ['#NLP', 'is', 'super', 'fun', '!', '<3', '#learning'], ['Thanks', '@datacamp', ':)', '#nlp', '#python']]

# %% [markdown]
# ## Non Ascii Tokenization

# %%
german_text = 'Wann gehen wir Pizza essen? 🍕 Und fährst du mit Über? 🚕'

all_words = word_tokenize(german_text)
print(all_words)
# Out:
# ['Wann', 'gehen', 'wir', 'Pizza', 'essen', '?', '🍕', 'Und', 'fährst', 'du', 'mit', 'Über', '?', '🚕']

# %%
# Tokenize and print all words in german_text
all_words = word_tokenize(german_text)
print(all_words)
# Out:
# ['Wann', 'gehen', 'wir', 'Pizza', 'essen', '?', '🍕', 'Und', 'fährst', 'du', 'mit', 'Über', '?', '🚕']

# %%
# Tokenize and print only capital words
capital_words = r"[A-Z|Ü]\w+"
print(regexp_tokenize(german_text, capital_words))

# Tokenize and print only emoji
emoji = "['\U0001F300-\U0001F5FF'|'\U0001F600-\U0001F64F'|'\U0001F680-\U0001F6FF'|'\u2600-\u26FF\u2700-\u27BF']"
print(regexp_tokenize(german_text, emoji))
# Out:
# ['Wann', 'Pizza', 'Und', 'Über']
# ['🍕', '🚕']

# %%
from matplotlib import pyplot as plt
filename = "holy_grail.txt"
file = open(filename, "r")
holy_grail = file.read()
#holy_grail

# %%
# Split the script into lines: lines
lines = holy_grail.split('\\n')
#lines

# Replace all script lines for speaker
pattern = "[A-Z]{2,}(\s)?(#\d)?([A-Z]{2,})?:"
lines = [re.sub(pattern, '', l) for l in lines]
lines
# Out:
# ['"SCENE 1: [wind] [clop clop clop] ',
#  ' Whoa there!  [clop clop clop] ',
#  ' Halt!  Who goes there?',
#  ' It is I, Arthur, son of Uther Pendragon, from the castle of Camelot.  King of the Britons, defeator of the Saxons, sovereign of all England!',
#  ' Pull the other one!',
#  ' I am, ...  and this is my trusty servant Patsy.  We have ridden the length and breadth of the land in search of knights who will join me in my court at Camelot.  I must speak with your lord and master.',
#  ' What?  Ridden on a horse?',
#  ' Yes!',
#  " You're using coconuts!",
#  ' What?',
#  " You've got two empty halves of coconut and you're bangin' 'em together.",
#  ' So?  We have ridden since the snows of winter covered this land, through the kingdom of Mercea, through--',
#  " Where'd you get the coconuts?",
#  ' We found them.',
#  " Found them?  In Mercea?  The coconut's tropical!",
#  ' What do you mean?',
#  ' Well, this is a temperate zone.',
# ...

# %%
# Tokenize each line: tokenized_lines
tokenized_lines = [regexp_tokenize(s, "\w+") for s in lines]
#tokenized_lines

# Make a frequency list of lengths: line_num_words
line_num_words = [len(t_line) for t_line in tokenized_lines]
# line_num_words

# Plot a histogram of the line lengths
plt.hist(line_num_words)
plt.show()

# %%
# introducing grams
my_text = "I would like to extract the 2 consequitive words from this paragraph. Each consequtive word set are called bigrams"
my_words = word_tokenize(my_text)

print(my_words)
# Out:
# ['I', 'would', 'like', 'to', 'extract', 'the', '2', 'consequitive', 'words', 'from', 'this', 'paragraph', '.', 'Each', 'consequtive', 'word', 'set', 'are', 'called', 'bigrams']

# %%
from nltk.util import ngrams

# %%
my_grams = ngrams(my_words,2)

# print(my_grams)
# To print n-grams, covert to list object

list(my_grams)
# Out:
# [('I', 'would'),
#  ('would', 'like'),
#  ('like', 'to'),
#  ('to', 'extract'),
#  ('extract', 'the'),
#  ('the', '2'),
#  ('2', 'consequitive'),
#  ('consequitive', 'words'),
#  ('words', 'from'),
#  ('from', 'this'),
#  ('this', 'paragraph'),
#  ('paragraph', '.'),
#  ('.', 'Each'),
#  ('Each', 'consequtive'),
#  ('consequtive', 'word'),
#  ('word', 'set'),
#  ('set', 'are'),
#  ('are', 'called'),
#  ('called', 'bigrams')]
